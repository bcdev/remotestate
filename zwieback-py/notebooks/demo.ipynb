# %%
import zwieback as zw

# %%
store = zw.Store({"count": 42})

# %%
class MyService(zw.Service):
    @zw.action
    async def increment(self):
        self.store.set("count", self.store.get("count") + 1)

# %%
zw.serve(
    MyService(store), 
    dist_dir="../../../zwieback-demo/dist", 
    iframe_height=200,
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 zw.serve(
#       2     MyService(store),
#       3     dist_dir="../../../zwieback-demo/dist",
#       4     iframe_height=200,
#
# File ~\Projects\zwieback\zwieback-py\src\zwieback\serve.py:73, in serve(service, dist_dir, mounts, host, port, open_browser, open_iframe, iframe_height)
#      71 mounts_ = dict(mounts) if mounts else {}
#      72 if dist_dir is not None:
# ---> 73     mounts_["/app"] = StaticFiles(directory=dist_dir, html=True)
#      75 zw_server = Server(service=service, mounts=mounts_)
#      77 uv_config = uvicorn.Config(
#      78     zw_server.app,
#      79     host=host,
#      80     port=port,
#      81     log_level="info",
#      82 )
#
# File ~\Projects\zwieback\zwieback-py\.pixi\envs\default\Lib\site-packages\starlette\staticfiles.py:56, in StaticFiles.__init__(self, directory, packages, html, check_dir, follow_symlink)
#      54 self.follow_symlink = follow_symlink
#      55 if check_dir and directory is not None and not os.path.isdir(directory):
# ---> 56     raise RuntimeError(f"Directory '{directory}' does not exist")
#
# RuntimeError: Directory '../../../zwieback-demo/dist' does not exist
